# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000,high=90.000,size=2000)
lngs = np.random.uniform(low=-180.000,high=180.000,size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

#print(coordinates)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
# YOUR CODE HERE
cities = []
# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 753

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
#print(url)

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()

        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
 
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_tmp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = city_weather["weather"][0]["description"]
      
            
        # Append the city information into the city_data list

        city_data.append({"City" :city.title(),
                         "Lat" : city_lat,
                         "Lng" : city_lng,
                         "Max Temp" : city_max_tmp,
                         "Humidity" : city_humidity,
                         "Cloudiness" : city_clouds,
                         "Wind Speed" : city_wind,
                         "Country" : city_country,
                         "Current Description" : city_weather_desc}
            
        )
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | lavrentiya
# Processing Record 2 of Set 1 | kandrian
# Processing Record 3 of Set 1 | port elizabeth
# Processing Record 4 of Set 1 | saskylakh
# Processing Record 5 of Set 1 | ahipara
# Processing Record 6 of Set 1 | bluff
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | aasiaat
# Processing Record 10 of Set 1 | jamestown
# Processing Record 11 of Set 1 | tiksi
# Processing Record 12 of Set 1 | hilo
# Processing Record 13 of Set 1 | bethel
# Processing Record 14 of Set 1 | chelno-vershiny
# Processing Record 15 of Set 1 | butaritari
# Processing Record 16 of Set 1 | wisconsin rapids
# Processing Record 17 of Set 1 | faya
# Processing Record 18 of Set 1 | elat
# Processing Record 19 of Set 1 | ostrovnoy
# Processing Record 20 of Set 1 | hobart
# Processing Record 21 of Set 1 | pisco
# Processing Record 22 of Set 1 | cape town
# Processing Record 23 of Set 1 | upernavik
# Processing Record 24 of Set 1 | khash
# Processing Record 25 of Set 1 | portland
# Processing Record 26 of Set 1 | port alfred
# Processing Record 27 of Set 1 | albany
# Processing Record 28 of Set 1 | hamilton
# Processing Record 29 of Set 1 | georgetown
# Processing Record 30 of Set 1 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 31 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 32 of Set 1 | axim
# Processing Record 33 of Set 1 | sola
# Processing Record 34 of Set 1 | leonidovo
# Processing Record 35 of Set 1 | ibarra
# Processing Record 36 of Set 1 | hofn
# Processing Record 37 of Set 1 | kaitangata
# Processing Record 38 of Set 1 | vaini
# Processing Record 39 of Set 1 | homer
# Processing Record 40 of Set 1 | bredasdorp
# Processing Record 41 of Set 1 | sri aman
# Processing Record 42 of Set 1 | pangnirtung
# Processing Record 43 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 44 of Set 1 | teknaf
# Processing Record 45 of Set 1 | dera bugti
# Processing Record 46 of Set 1 | tomatlan
# Processing Record 47 of Set 1 | torbay
# Processing Record 48 of Set 1 | iranshahr
# Processing Record 49 of Set 1 | kendal
# Processing Record 50 of Set 1 | williams lake
# Processing Record 1 of Set 2 | ushuaia
# Processing Record 2 of Set 2 | iqaluit
# Processing Record 3 of Set 2 | omsukchan
# Processing Record 4 of Set 2 | avarua
# Processing Record 5 of Set 2 | barrow
# Processing Record 6 of Set 2 | chuy
# Processing Record 7 of Set 2 | castro
# Processing Record 8 of Set 2 | saint-pierre
# Processing Record 9 of Set 2 | thompson
# Processing Record 10 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 2 | mahebourg
# Processing Record 12 of Set 2 | dikson
# Processing Record 13 of Set 2 | palana
# Processing Record 14 of Set 2 | sao gabriel da cachoeira
# Processing Record 15 of Set 2 | port blair
# Processing Record 16 of Set 2 | kahului
# Processing Record 17 of Set 2 | mount gambier
# Processing Record 18 of Set 2 | husavik
# Processing Record 19 of Set 2 | pamplona
# Processing Record 20 of Set 2 | yulara
# Processing Record 21 of Set 2 | guerrero negro
# Processing Record 22 of Set 2 | ewo
# Processing Record 23 of Set 2 | mayor pablo lagerenza
# Processing Record 24 of Set 2 | puerto ayora
# Processing Record 25 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 26 of Set 2 | grand centre
# City not found. Skipping...
# Processing Record 27 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 28 of Set 2 | constitucion
# Processing Record 29 of Set 2 | new norfolk
# Processing Record 30 of Set 2 | charters towers
# Processing Record 31 of Set 2 | taoudenni
# Processing Record 32 of Set 2 | kodiak
# Processing Record 33 of Set 2 | trairi
# Processing Record 34 of Set 2 | miraflores
# Processing Record 35 of Set 2 | te anau
# Processing Record 36 of Set 2 | ijaki
# City not found. Skipping...
# Processing Record 37 of Set 2 | dinghai
# Processing Record 38 of Set 2 | seoul
# Processing Record 39 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 2 | mataura
# Processing Record 41 of Set 2 | kopervik
# Processing Record 42 of Set 2 | arraial do cabo
# Processing Record 43 of Set 2 | saint-philippe
# Processing Record 44 of Set 2 | cutlerville
# Processing Record 45 of Set 2 | airai
# Processing Record 46 of Set 2 | port said
# Processing Record 47 of Set 2 | byron bay
# Processing Record 48 of Set 2 | hermanus
# Processing Record 49 of Set 2 | mayo
# Processing Record 50 of Set 2 | urumqi
# Processing Record 1 of Set 3 | biak
# Processing Record 2 of Set 3 | souillac
# Processing Record 3 of Set 3 | urubicha
# Processing Record 4 of Set 3 | salinopolis
# Processing Record 5 of Set 3 | lebu
# Processing Record 6 of Set 3 | atuona
# Processing Record 7 of Set 3 | haines junction
# Processing Record 8 of Set 3 | digby
# Processing Record 9 of Set 3 | banda aceh
# Processing Record 10 of Set 3 | witu
# Processing Record 11 of Set 3 | alice springs
# Processing Record 12 of Set 3 | nguiu
# City not found. Skipping...
# Processing Record 13 of Set 3 | cabedelo
# Processing Record 14 of Set 3 | skjervoy
# Processing Record 15 of Set 3 | hithadhoo
# Processing Record 16 of Set 3 | morondava
# Processing Record 17 of Set 3 | viedma
# Processing Record 18 of Set 3 | montrose
# Processing Record 19 of Set 3 | pimentel
# Processing Record 20 of Set 3 | ekhabi
# Processing Record 21 of Set 3 | chapais
# Processing Record 22 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 23 of Set 3 | mar del plata
# Processing Record 24 of Set 3 | tasiilaq
# Processing Record 25 of Set 3 | east london
# Processing Record 26 of Set 3 | pitimbu
# Processing Record 27 of Set 3 | abu dhabi
# Processing Record 28 of Set 3 | san andres
# Processing Record 29 of Set 3 | hobyo
# Processing Record 30 of Set 3 | luderitz
# Processing Record 31 of Set 3 | bambanglipuro
# Processing Record 32 of Set 3 | klaksvik
# Processing Record 33 of Set 3 | camacha
# Processing Record 34 of Set 3 | caravelas
# Processing Record 35 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 36 of Set 3 | tuatapere
# Processing Record 37 of Set 3 | la asuncion
# Processing Record 38 of Set 3 | sambava
# Processing Record 39 of Set 3 | talnakh
# Processing Record 40 of Set 3 | lorengau
# Processing Record 41 of Set 3 | salalah
# Processing Record 42 of Set 3 | canita
# Processing Record 43 of Set 3 | agirish
# Processing Record 44 of Set 3 | victoria
# Processing Record 45 of Set 3 | bakong
# Processing Record 46 of Set 3 | karkaralinsk
# City not found. Skipping...
# Processing Record 47 of Set 3 | yellowknife
# Processing Record 48 of Set 3 | tuktoyaktuk
# Processing Record 49 of Set 3 | alofi
# Processing Record 50 of Set 3 | tecoanapa
# Processing Record 1 of Set 4 | bambous virieux
# Processing Record 2 of Set 4 | south houston
# Processing Record 3 of Set 4 | bereda
# Processing Record 4 of Set 4 | miri
# Processing Record 5 of Set 4 | boyolangu
# Processing Record 6 of Set 4 | atar
# Processing Record 7 of Set 4 | moron
# Processing Record 8 of Set 4 | juifang
# City not found. Skipping...
# Processing Record 9 of Set 4 | nakamura
# Processing Record 10 of Set 4 | esperance
# Processing Record 11 of Set 4 | sorong
# Processing Record 12 of Set 4 | kapaa
# Processing Record 13 of Set 4 | faanui
# Processing Record 14 of Set 4 | falmouth
# Processing Record 15 of Set 4 | provideniya
# Processing Record 16 of Set 4 | qaanaaq
# Processing Record 17 of Set 4 | sitka
# Processing Record 18 of Set 4 | norman wells
# Processing Record 19 of Set 4 | hay river
# Processing Record 20 of Set 4 | konde
# Processing Record 21 of Set 4 | cayenne
# Processing Record 22 of Set 4 | khatanga
# Processing Record 23 of Set 4 | wenzhou
# Processing Record 24 of Set 4 | asau
# Processing Record 25 of Set 4 | busselton
# Processing Record 26 of Set 4 | yeppoon
# Processing Record 27 of Set 4 | solotcha
# Processing Record 28 of Set 4 | yumen
# Processing Record 29 of Set 4 | san patricio
# Processing Record 30 of Set 4 | mojoagung
# Processing Record 31 of Set 4 | katsuura
# Processing Record 32 of Set 4 | abu samrah
# Processing Record 33 of Set 4 | kavaratti
# Processing Record 34 of Set 4 | kalemie
# Processing Record 35 of Set 4 | vila velha
# Processing Record 36 of Set 4 | xichang
# Processing Record 37 of Set 4 | ornskoldsvik
# Processing Record 38 of Set 4 | leningradskiy
# Processing Record 39 of Set 4 | codrington
# Processing Record 40 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 41 of Set 4 | balkhash
# Processing Record 42 of Set 4 | qiongshan
# Processing Record 43 of Set 4 | hami
# Processing Record 44 of Set 4 | pesqueria
# Processing Record 45 of Set 4 | hurghada
# Processing Record 46 of Set 4 | moerai
# Processing Record 47 of Set 4 | nago
# Processing Record 48 of Set 4 | ponta delgada
# Processing Record 49 of Set 4 | samarai
# Processing Record 50 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 1 of Set 5 | nome
# Processing Record 2 of Set 5 | daru
# Processing Record 3 of Set 5 | jiutai
# Processing Record 4 of Set 5 | zaraza
# Processing Record 5 of Set 5 | baykit
# Processing Record 6 of Set 5 | clyde river
# Processing Record 7 of Set 5 | hibbing
# Processing Record 8 of Set 5 | bowen
# Processing Record 9 of Set 5 | college
# Processing Record 10 of Set 5 | miranda de ebro
# Processing Record 11 of Set 5 | manokwari
# Processing Record 12 of Set 5 | baker city
# Processing Record 13 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 14 of Set 5 | fleetwood
# Processing Record 15 of Set 5 | zverinogolovskoye
# Processing Record 16 of Set 5 | severo-kurilsk
# Processing Record 17 of Set 5 | nuuk
# Processing Record 18 of Set 5 | sept-iles
# Processing Record 19 of Set 5 | doka
# Processing Record 20 of Set 5 | lasa
# Processing Record 21 of Set 5 | umm lajj
# Processing Record 22 of Set 5 | ilulissat
# Processing Record 23 of Set 5 | dingle
# Processing Record 24 of Set 5 | changping
# Processing Record 25 of Set 5 | vilhena
# Processing Record 26 of Set 5 | machinga
# Processing Record 27 of Set 5 | ermoupolis
# Processing Record 28 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 29 of Set 5 | labuhan
# Processing Record 30 of Set 5 | vallenar
# Processing Record 31 of Set 5 | jibuti
# Processing Record 32 of Set 5 | taburao
# City not found. Skipping...
# Processing Record 33 of Set 5 | sao jose da coroa grande
# Processing Record 34 of Set 5 | zlynka
# Processing Record 35 of Set 5 | kavieng
# Processing Record 36 of Set 5 | altay
# Processing Record 37 of Set 5 | hasaki
# Processing Record 38 of Set 5 | carnarvon
# Processing Record 39 of Set 5 | saldanha
# Processing Record 40 of Set 5 | san isidro
# Processing Record 41 of Set 5 | nikolskoye
# Processing Record 42 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 43 of Set 5 | xuddur
# Processing Record 44 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 45 of Set 5 | longyearbyen
# Processing Record 46 of Set 5 | hovd
# Processing Record 47 of Set 5 | olafsvik
# Processing Record 48 of Set 5 | kholodnyy
# Processing Record 49 of Set 5 | doha
# Processing Record 50 of Set 5 | trinidad
# Processing Record 1 of Set 6 | patzicia
# Processing Record 2 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 3 of Set 6 | talara
# Processing Record 4 of Set 6 | srednekolymsk
# Processing Record 5 of Set 6 | kununurra
# Processing Record 6 of Set 6 | san ignacio
# Processing Record 7 of Set 6 | madimba
# Processing Record 8 of Set 6 | shiyan
# Processing Record 9 of Set 6 | panaba
# Processing Record 10 of Set 6 | saint george
# Processing Record 11 of Set 6 | praia da vitoria
# Processing Record 12 of Set 6 | severo-yeniseyskiy
# Processing Record 13 of Set 6 | oudtshoorn
# Processing Record 14 of Set 6 | karpathos
# Processing Record 15 of Set 6 | nargana
# Processing Record 16 of Set 6 | san agustin
# Processing Record 17 of Set 6 | taywarah
# Processing Record 18 of Set 6 | astipalaia
# City not found. Skipping...
# Processing Record 19 of Set 6 | kutum
# Processing Record 20 of Set 6 | ngerengere
# Processing Record 21 of Set 6 | salamanca
# Processing Record 22 of Set 6 | bengkulu
# Processing Record 23 of Set 6 | pundaguitan
# Processing Record 24 of Set 6 | hambantota
# Processing Record 25 of Set 6 | korla
# Processing Record 26 of Set 6 | westerland
# Processing Record 27 of Set 6 | malpe
# Processing Record 28 of Set 6 | bilibino
# Processing Record 29 of Set 6 | sao filipe
# Processing Record 30 of Set 6 | skalistyy
# City not found. Skipping...
# Processing Record 31 of Set 6 | nouadhibou
# Processing Record 32 of Set 6 | domodossola
# Processing Record 33 of Set 6 | la roda
# Processing Record 34 of Set 6 | mizdah
# Processing Record 35 of Set 6 | broken hill
# Processing Record 36 of Set 6 | nanortalik
# Processing Record 37 of Set 6 | rocha
# Processing Record 38 of Set 6 | zhmerynka
# Processing Record 39 of Set 6 | oranjemund
# Processing Record 40 of Set 6 | essex
# Processing Record 41 of Set 6 | contai
# Processing Record 42 of Set 6 | najran
# Processing Record 43 of Set 6 | naryan-mar
# Processing Record 44 of Set 6 | kalmunai
# Processing Record 45 of Set 6 | ulaanbaatar
# Processing Record 46 of Set 6 | bulgan
# Processing Record 47 of Set 6 | hailey
# Processing Record 48 of Set 6 | padang
# Processing Record 49 of Set 6 | la ronge
# Processing Record 50 of Set 6 | formosa do rio preto
# Processing Record 1 of Set 7 | ponta do sol
# Processing Record 2 of Set 7 | bulaevo
# Processing Record 3 of Set 7 | zalantun
# Processing Record 4 of Set 7 | loubomo
# Processing Record 5 of Set 7 | ca mau
# Processing Record 6 of Set 7 | lensk
# Processing Record 7 of Set 7 | dawson creek
# Processing Record 8 of Set 7 | soderhamn
# Processing Record 9 of Set 7 | mackenzie
# Processing Record 10 of Set 7 | saint marys
# Processing Record 11 of Set 7 | medicine hat
# Processing Record 12 of Set 7 | ancud
# Processing Record 13 of Set 7 | sanlucar de barrameda
# Processing Record 14 of Set 7 | meulaboh
# Processing Record 15 of Set 7 | haverfordwest
# Processing Record 16 of Set 7 | san joaquin
# Processing Record 17 of Set 7 | willmar
# Processing Record 18 of Set 7 | bisira
# Processing Record 19 of Set 7 | vardo
# Processing Record 20 of Set 7 | olinda
# Processing Record 21 of Set 7 | kaseda
# Processing Record 22 of Set 7 | palasa
# Processing Record 23 of Set 7 | vanimo
# Processing Record 24 of Set 7 | haldibari
# Processing Record 25 of Set 7 | gamba
# Processing Record 26 of Set 7 | jennings
# Processing Record 27 of Set 7 | espinal
# Processing Record 28 of Set 7 | bonavista
# Processing Record 29 of Set 7 | rolla
# Processing Record 30 of Set 7 | hirara
# Processing Record 31 of Set 7 | jacmel
# Processing Record 32 of Set 7 | nishihara
# Processing Record 33 of Set 7 | jalu
# Processing Record 34 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 35 of Set 7 | surt
# Processing Record 36 of Set 7 | loikaw
# Processing Record 37 of Set 7 | kirakira
# Processing Record 38 of Set 7 | dunedin
# Processing Record 39 of Set 7 | kapit
# Processing Record 40 of Set 7 | saint-leu
# Processing Record 41 of Set 7 | mareeba
# Processing Record 42 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 43 of Set 7 | kudahuvadhoo
# Processing Record 44 of Set 7 | bubaque
# Processing Record 45 of Set 7 | deputatskiy
# Processing Record 46 of Set 7 | flinders
# Processing Record 47 of Set 7 | osakarovka
# Processing Record 48 of Set 7 | sao joao da barra
# Processing Record 49 of Set 7 | lata
# Processing Record 50 of Set 7 | oksfjord
# Processing Record 1 of Set 8 | egvekinot
# Processing Record 2 of Set 8 | salvador
# Processing Record 3 of Set 8 | saint anthony
# Processing Record 4 of Set 8 | jaisalmer
# Processing Record 5 of Set 8 | neuquen
# Processing Record 6 of Set 8 | liniere
# City not found. Skipping...
# Processing Record 7 of Set 8 | barawe
# City not found. Skipping...
# Processing Record 8 of Set 8 | zima
# Processing Record 9 of Set 8 | coihaique
# Processing Record 10 of Set 8 | bari
# Processing Record 11 of Set 8 | fortuna
# Processing Record 12 of Set 8 | lompoc
# Processing Record 13 of Set 8 | aljezur
# Processing Record 14 of Set 8 | dudinka
# Processing Record 15 of Set 8 | preobrazheniye
# Processing Record 16 of Set 8 | gat
# Processing Record 17 of Set 8 | tautira
# Processing Record 18 of Set 8 | whitianga
# Processing Record 19 of Set 8 | puerto princesa
# Processing Record 20 of Set 8 | vigrestad
# Processing Record 21 of Set 8 | limon
# Processing Record 22 of Set 8 | tuggurt
# City not found. Skipping...
# Processing Record 23 of Set 8 | maposeni
# Processing Record 24 of Set 8 | hayvoron
# Processing Record 25 of Set 8 | milkovo
# Processing Record 26 of Set 8 | cidreira
# Processing Record 27 of Set 8 | kiunga
# Processing Record 28 of Set 8 | abrau-dyurso
# Processing Record 29 of Set 8 | tiarei
# Processing Record 30 of Set 8 | ribeira grande
# Processing Record 31 of Set 8 | korem
# Processing Record 32 of Set 8 | sault sainte marie
# Processing Record 33 of Set 8 | novyy urengoy
# Processing Record 34 of Set 8 | danshui
# Processing Record 35 of Set 8 | laguna
# Processing Record 36 of Set 8 | kilosa
# Processing Record 37 of Set 8 | gao
# Processing Record 38 of Set 8 | prince rupert
# Processing Record 39 of Set 8 | palmer
# Processing Record 40 of Set 8 | vila franca do campo
# Processing Record 41 of Set 8 | cabo rojo
# Processing Record 42 of Set 8 | beausejour
# Processing Record 43 of Set 8 | sibu
# Processing Record 44 of Set 8 | vanavara
# Processing Record 45 of Set 8 | vung tau
# Processing Record 46 of Set 8 | taicheng
# Processing Record 47 of Set 8 | ucluelet
# Processing Record 48 of Set 8 | igarka
# Processing Record 49 of Set 8 | cabrobo
# Processing Record 50 of Set 8 | sao felix do xingu
# Processing Record 1 of Set 9 | montepuez
# Processing Record 2 of Set 9 | mirnyy
# Processing Record 3 of Set 9 | mutoko
# Processing Record 4 of Set 9 | narsaq
# Processing Record 5 of Set 9 | kabare
# Processing Record 6 of Set 9 | sai buri
# Processing Record 7 of Set 9 | cherskiy
# Processing Record 8 of Set 9 | beira
# Processing Record 9 of Set 9 | shelburne
# Processing Record 10 of Set 9 | phan thiet
# Processing Record 11 of Set 9 | ostersund
# Processing Record 12 of Set 9 | tapes
# Processing Record 13 of Set 9 | kytlym
# City not found. Skipping...
# Processing Record 14 of Set 9 | port macquarie
# Processing Record 15 of Set 9 | vargashi
# Processing Record 16 of Set 9 | mehamn
# Processing Record 17 of Set 9 | batagay
# Processing Record 18 of Set 9 | chicama
# Processing Record 19 of Set 9 | shebunino
# Processing Record 20 of Set 9 | rennes
# Processing Record 21 of Set 9 | dakar
# Processing Record 22 of Set 9 | lysa hora
# Processing Record 23 of Set 9 | boden
# Processing Record 24 of Set 9 | acolla
# Processing Record 25 of Set 9 | savannah bight
# Processing Record 26 of Set 9 | hof
# Processing Record 27 of Set 9 | tekax
# City not found. Skipping...
# Processing Record 28 of Set 9 | vao
# Processing Record 29 of Set 9 | guider
# Processing Record 30 of Set 9 | port hardy
# Processing Record 31 of Set 9 | kruisfontein
# Processing Record 32 of Set 9 | brae
# Processing Record 33 of Set 9 | gemena
# Processing Record 34 of Set 9 | hearst
# Processing Record 35 of Set 9 | huarmey
# Processing Record 36 of Set 9 | den helder
# Processing Record 37 of Set 9 | jumla
# Processing Record 38 of Set 9 | polis
# Processing Record 39 of Set 9 | namtsy
# Processing Record 40 of Set 9 | tual
# Processing Record 41 of Set 9 | usinsk
# Processing Record 42 of Set 9 | launceston
# Processing Record 43 of Set 9 | yining
# Processing Record 44 of Set 9 | uhlove
# Processing Record 45 of Set 9 | tasbuget
# City not found. Skipping...
# Processing Record 46 of Set 9 | nhulunbuy
# Processing Record 47 of Set 9 | tongliao
# Processing Record 48 of Set 9 | mutare
# Processing Record 49 of Set 9 | kemi
# Processing Record 50 of Set 9 | lagoa
# Processing Record 1 of Set 10 | west bay
# Processing Record 2 of Set 10 | beringovskiy
# Processing Record 3 of Set 10 | puerto colombia
# Processing Record 4 of Set 10 | diamantino
# Processing Record 5 of Set 10 | aswan
# Processing Record 6 of Set 10 | mariental
# Processing Record 7 of Set 10 | svetlaya
# Processing Record 8 of Set 10 | leshukonskoye
# Processing Record 9 of Set 10 | san quintin
# Processing Record 10 of Set 10 | grindavik
# Processing Record 11 of Set 10 | karasjok
# Processing Record 12 of Set 10 | rio gallegos
# Processing Record 13 of Set 10 | urdzhar
# City not found. Skipping...
# Processing Record 14 of Set 10 | darhan
# Processing Record 15 of Set 10 | waingapu
# Processing Record 16 of Set 10 | angra
# City not found. Skipping...
# Processing Record 17 of Set 10 | shobara
# Processing Record 18 of Set 10 | uglovskoye
# Processing Record 19 of Set 10 | poum
# Processing Record 20 of Set 10 | dalby
# Processing Record 21 of Set 10 | tara
# Processing Record 22 of Set 10 | islampur
# Processing Record 23 of Set 10 | sliema
# Processing Record 24 of Set 10 | ramnagar
# Processing Record 25 of Set 10 | taltal
# Processing Record 26 of Set 10 | houma
# Processing Record 27 of Set 10 | puerto escondido
# Processing Record 28 of Set 10 | pampa
# Processing Record 29 of Set 10 | yablonovo
# Processing Record 30 of Set 10 | tura
# Processing Record 31 of Set 10 | kez
# Processing Record 32 of Set 10 | veraval
# Processing Record 33 of Set 10 | skiros
# City not found. Skipping...
# Processing Record 34 of Set 10 | folkestone
# Processing Record 35 of Set 10 | minas de barroteran
# Processing Record 36 of Set 10 | okuchi
# Processing Record 37 of Set 10 | sechura
# Processing Record 38 of Set 10 | pringsewu
# Processing Record 39 of Set 10 | aksu
# Processing Record 40 of Set 10 | mahajanga
# Processing Record 41 of Set 10 | buraydah
# Processing Record 42 of Set 10 | geraldton
# Processing Record 43 of Set 10 | riyadh
# Processing Record 44 of Set 10 | dzaoudzi
# Processing Record 45 of Set 10 | gizo
# Processing Record 46 of Set 10 | kokstad
# Processing Record 47 of Set 10 | mangan
# Processing Record 48 of Set 10 | kawalu
# Processing Record 49 of Set 10 | we
# City not found. Skipping...
# Processing Record 50 of Set 10 | farsund
# Processing Record 1 of Set 11 | plainfield
# Processing Record 2 of Set 11 | mao
# Processing Record 3 of Set 11 | yakeshi
# Processing Record 4 of Set 11 | harper
# Processing Record 5 of Set 11 | shieli
# Processing Record 6 of Set 11 | saint-denis
# Processing Record 7 of Set 11 | oskaloosa
# Processing Record 8 of Set 11 | itapua poty
# City not found. Skipping...
# Processing Record 9 of Set 11 | puerto carreno
# Processing Record 10 of Set 11 | nouakchott
# Processing Record 11 of Set 11 | sakakah
# Processing Record 12 of Set 11 | qaqortoq
# Processing Record 13 of Set 11 | soc trang
# Processing Record 14 of Set 11 | wagar
# Processing Record 15 of Set 11 | a
# City not found. Skipping...
# Processing Record 16 of Set 11 | lemesos
# City not found. Skipping...
# Processing Record 17 of Set 11 | maiduguri
# Processing Record 18 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 19 of Set 11 | urucara
# Processing Record 20 of Set 11 | puerto del rosario
# Processing Record 21 of Set 11 | arlit
# Processing Record 22 of Set 11 | aykhal
# Processing Record 23 of Set 11 | eresos
# Processing Record 24 of Set 11 | sioux lookout
# Processing Record 25 of Set 11 | puerto madryn
# Processing Record 26 of Set 11 | anadyr
# Processing Record 27 of Set 11 | cabildo
# Processing Record 28 of Set 11 | plettenberg bay
# Processing Record 29 of Set 11 | turbat
# Processing Record 30 of Set 11 | mosquera
# Processing Record 31 of Set 11 | kibala
# Processing Record 32 of Set 11 | nalut
# Processing Record 33 of Set 11 | anloga
# Processing Record 34 of Set 11 | chokurdakh
# Processing Record 35 of Set 11 | san francisco del mar
# Processing Record 36 of Set 11 | cartagena
# Processing Record 37 of Set 11 | strezhevoy
# Processing Record 38 of Set 11 | kargasok
# Processing Record 39 of Set 11 | paamiut
# Processing Record 40 of Set 11 | batagay-alyta
# Processing Record 41 of Set 11 | samandag
# Processing Record 42 of Set 11 | novobureyskiy
# Processing Record 43 of Set 11 | palora
# Processing Record 44 of Set 11 | sanok
# Processing Record 45 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 46 of Set 11 | mount isa
# Processing Record 47 of Set 11 | keti bandar
# Processing Record 48 of Set 11 | canutama
# Processing Record 49 of Set 11 | port-gentil
# Processing Record 50 of Set 11 | pevek
# Processing Record 1 of Set 12 | zhigansk
# Processing Record 2 of Set 12 | la rioja
# Processing Record 3 of Set 12 | srandakan
# Processing Record 4 of Set 12 | havelock
# Processing Record 5 of Set 12 | fuerte
# Processing Record 6 of Set 12 | namibe
# Processing Record 7 of Set 12 | sherghati
# Processing Record 8 of Set 12 | dalnerechensk
# Processing Record 9 of Set 12 | rovaniemi
# Processing Record 10 of Set 12 | neyshabur
# Processing Record 11 of Set 12 | touros
# Processing Record 12 of Set 12 | kayerkan
# Processing Record 13 of Set 12 | shimoda
# Processing Record 14 of Set 12 | san francisco
# Processing Record 15 of Set 12 | zhuhai
# Processing Record 16 of Set 12 | svistov
# City not found. Skipping...
# Processing Record 17 of Set 12 | carupano
# Processing Record 18 of Set 12 | belmonte
# Processing Record 19 of Set 12 | miandrivazo
# Processing Record 20 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 21 of Set 12 | shingu
# Processing Record 22 of Set 12 | liepaja
# Processing Record 23 of Set 12 | zemio
# Processing Record 24 of Set 12 | beyneu
# Processing Record 25 of Set 12 | catuday
# Processing Record 26 of Set 12 | cabo san lucas
# Processing Record 27 of Set 12 | tommot
# Processing Record 28 of Set 12 | williamsburg
# Processing Record 29 of Set 12 | wanaka
# Processing Record 30 of Set 12 | raudeberg
# Processing Record 31 of Set 12 | porto velho
# Processing Record 32 of Set 12 | bad lippspringe
# Processing Record 33 of Set 12 | develi
# Processing Record 34 of Set 12 | onega
# Processing Record 35 of Set 12 | kodinsk
# Processing Record 36 of Set 12 | okhotsk
# Processing Record 37 of Set 12 | garoua
# Processing Record 38 of Set 12 | nemuro
# Processing Record 39 of Set 12 | pokhara
# Processing Record 40 of Set 12 | lahij
# Processing Record 41 of Set 12 | corrales
# Processing Record 42 of Set 12 | maniitsoq
# Processing Record 43 of Set 12 | hede
# Processing Record 44 of Set 12 | gidam
# Processing Record 45 of Set 12 | okitipupa
# Processing Record 46 of Set 12 | almaznyy
# Processing Record 47 of Set 12 | teguise
# Processing Record 48 of Set 12 | la cruz
# Processing Record 49 of Set 12 | tongren
# Processing Record 50 of Set 12 | aklavik
# Processing Record 1 of Set 13 | taganak
# Processing Record 2 of Set 13 | belaya gora
# Processing Record 3 of Set 13 | ust-kuyga
# Processing Record 4 of Set 13 | male
# Processing Record 5 of Set 13 | blackfoot
# Processing Record 6 of Set 13 | kailua
# Processing Record 7 of Set 13 | beisfjord
# Processing Record 8 of Set 13 | westport
# Processing Record 9 of Set 13 | elizabeth city
# Processing Record 10 of Set 13 | ye
# City not found. Skipping...
# Processing Record 11 of Set 13 | coquimbo
# Processing Record 12 of Set 13 | tambopata
# Processing Record 13 of Set 13 | fairbanks
# Processing Record 14 of Set 13 | omboue
# Processing Record 15 of Set 13 | bud
# Processing Record 16 of Set 13 | bintulu
# Processing Record 17 of Set 13 | bandarbeyla
# Processing Record 18 of Set 13 | marigot
# Processing Record 19 of Set 13 | tabuk
# Processing Record 20 of Set 13 | isangel
# Processing Record 21 of Set 13 | yerbogachen
# Processing Record 22 of Set 13 | tahe
# Processing Record 23 of Set 13 | geylegphug
# City not found. Skipping...
# Processing Record 24 of Set 13 | cedar city
# Processing Record 25 of Set 13 | atherton
# Processing Record 26 of Set 13 | larsnes
# Processing Record 27 of Set 13 | panama city
# Processing Record 28 of Set 13 | katherine
# Processing Record 29 of Set 13 | kimbe
# Processing Record 30 of Set 13 | komsomolskiy
# Processing Record 31 of Set 13 | innisfail
# Processing Record 32 of Set 13 | mayumba
# Processing Record 33 of Set 13 | peniche
# Processing Record 34 of Set 13 | goure
# Processing Record 35 of Set 13 | bolshiye uki
# City not found. Skipping...
# Processing Record 36 of Set 13 | awbari
# Processing Record 37 of Set 13 | novoseleznevo
# Processing Record 38 of Set 13 | cockburn town
# Processing Record 39 of Set 13 | zomin
# Processing Record 40 of Set 13 | coolum beach
# Processing Record 41 of Set 13 | fort nelson
# Processing Record 42 of Set 13 | carutapera
# Processing Record 43 of Set 13 | hualmay
# Processing Record 44 of Set 13 | kropotkin
# Processing Record 45 of Set 13 | goderich
# Processing Record 46 of Set 13 | poya
# Processing Record 47 of Set 13 | talcahuano
# Processing Record 48 of Set 13 | naze
# Processing Record 49 of Set 13 | merauke
# Processing Record 50 of Set 13 | jinxi
# Processing Record 1 of Set 14 | dhidhdhoo
# Processing Record 2 of Set 14 | muisne
# Processing Record 3 of Set 14 | valparaiso
# Processing Record 4 of Set 14 | bokspits
# City not found. Skipping...
# Processing Record 5 of Set 14 | neiafu
# Processing Record 6 of Set 14 | buala
# Processing Record 7 of Set 14 | spornoye
# Processing Record 8 of Set 14 | magui
# City not found. Skipping...
# Processing Record 9 of Set 14 | ouro preto do oeste
# Processing Record 10 of Set 14 | urozhaynoye
# Processing Record 11 of Set 14 | santa cruz
# Processing Record 12 of Set 14 | porto novo
# Processing Record 13 of Set 14 | boundiali
# Processing Record 14 of Set 14 | huazolotitlan
# City not found. Skipping...
# Processing Record 15 of Set 14 | japura
# Processing Record 16 of Set 14 | ishigaki
# Processing Record 17 of Set 14 | westpunt
# City not found. Skipping...
# Processing Record 18 of Set 14 | pacifica
# Processing Record 19 of Set 14 | barreirinhas
# Processing Record 20 of Set 14 | mabaruma
# Processing Record 21 of Set 14 | pervomayskoye
# Processing Record 22 of Set 14 | high level
# Processing Record 23 of Set 14 | robertsport
# Processing Record 24 of Set 14 | tidore
# City not found. Skipping...
# Processing Record 25 of Set 14 | hokitika
# Processing Record 26 of Set 14 | aranos
# Processing Record 27 of Set 14 | ginir
# Processing Record 28 of Set 14 | calamar
# Processing Record 29 of Set 14 | kampong chhnang
# Processing Record 30 of Set 14 | sal rei
# Processing Record 31 of Set 14 | pithapuram
# Processing Record 32 of Set 14 | cancun
# Processing Record 33 of Set 14 | reinosa
# Processing Record 34 of Set 14 | arona
# Processing Record 35 of Set 14 | ortona
# Processing Record 36 of Set 14 | batticaloa
# Processing Record 37 of Set 14 | kapuskasing
# Processing Record 38 of Set 14 | mana
# Processing Record 39 of Set 14 | warri
# Processing Record 40 of Set 14 | mananjary
# Processing Record 41 of Set 14 | tanout
# Processing Record 42 of Set 14 | luanda
# Processing Record 43 of Set 14 | caxito
# Processing Record 44 of Set 14 | tessaoua
# Processing Record 45 of Set 14 | rialma
# Processing Record 46 of Set 14 | royal leamington spa
# Processing Record 47 of Set 14 | achisay
# City not found. Skipping...
# Processing Record 48 of Set 14 | vestmannaeyjar
# Processing Record 49 of Set 14 | yaan
# Processing Record 50 of Set 14 | khandyga
# Processing Record 1 of Set 15 | ngukurr
# City not found. Skipping...
# Processing Record 2 of Set 15 | maltahohe
# Processing Record 3 of Set 15 | carballo
# Processing Record 4 of Set 15 | naron
# Processing Record 5 of Set 15 | muncar
# Processing Record 6 of Set 15 | kiruna
# Processing Record 7 of Set 15 | tabarqah
# City not found. Skipping...
# Processing Record 8 of Set 15 | palomares
# Processing Record 9 of Set 15 | santa maria
# Processing Record 10 of Set 15 | moranbah
# Processing Record 11 of Set 15 | pilao arcado
# City not found. Skipping...
# Processing Record 12 of Set 15 | black river
# Processing Record 13 of Set 15 | palu
# Processing Record 14 of Set 15 | tsentralnyy
# City not found. Skipping...
# Processing Record 15 of Set 15 | kundiawa
# Processing Record 16 of Set 15 | burica
# City not found. Skipping...
# Processing Record 17 of Set 15 | flagstaff
# Processing Record 18 of Set 15 | itarema
# Processing Record 19 of Set 15 | kelso
# Processing Record 20 of Set 15 | ndjole
# Processing Record 21 of Set 15 | rapid valley
# Processing Record 22 of Set 15 | vizinga
# Processing Record 23 of Set 15 | moen
# Processing Record 24 of Set 15 | makakilo city
# Processing Record 25 of Set 15 | celestun
# Processing Record 26 of Set 15 | santiago
# Processing Record 27 of Set 15 | qasigiannguit
# Processing Record 28 of Set 15 | muros
# Processing Record 29 of Set 15 | poltavka
# Processing Record 30 of Set 15 | cumberland
# Processing Record 31 of Set 15 | santa ana
# Processing Record 32 of Set 15 | dankaur
# Processing Record 33 of Set 15 | labytnangi
# Processing Record 34 of Set 15 | broome
# Processing Record 35 of Set 15 | ganzhou
# Processing Record 36 of Set 15 | nyurba
# Processing Record 37 of Set 15 | taksimo
# Processing Record 38 of Set 15 | karratha
# Processing Record 39 of Set 15 | bafoulabe
# Processing Record 40 of Set 15 | lulea
# Processing Record 41 of Set 15 | sainte-suzanne
# Processing Record 42 of Set 15 | belaya
# Processing Record 43 of Set 15 | lilongwe
# Processing Record 44 of Set 15 | liberal
# Processing Record 45 of Set 15 | lashio
# Processing Record 46 of Set 15 | devils lake
# Processing Record 47 of Set 15 | dakoro
# Processing Record 48 of Set 15 | novikovo
# Processing Record 49 of Set 15 | quatre cocos
# Processing Record 50 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 1 of Set 16 | eyl
# Processing Record 2 of Set 16 | yamada
# Processing Record 3 of Set 16 | ankang
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 696

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Lavrentiya  65.5833 -171.0000     17.71        79         100
# 1        Kandrian  -6.2167  149.5500     75.61        89          89
# 2  Port Elizabeth -33.9180   25.5701     64.69        82           0
# 3       Saskylakh  71.9167  114.0833    -11.40        90         100
# 4         Ahipara -35.1667  173.1667     62.31        77          26
# 5           Bluff -46.6000  168.3333     58.80        77          51
# 6         Rikitea -23.1203 -134.9692     74.52        82         100
# 7    Punta Arenas -53.1500  -70.9167     66.22        51          75
# 8         Aasiaat  68.7098  -52.8699     16.27        99          99
# 9       Jamestown  42.0970  -79.2353     36.99        66         100
#
#    Wind Speed Country                 Date Current Description
# 0        4.25      RU  2022-11-14 18:32:08     overcast clouds
# 1        4.03      PG  2022-11-14 18:32:08     overcast clouds
# 2       20.71      ZA  2022-11-14 18:32:08           clear sky
# 3       10.18      RU  2022-11-14 18:32:08     overcast clouds
# 4        5.57      NZ  2022-11-14 18:32:08    scattered clouds
# 5       11.72      NZ  2022-11-14 18:32:08       broken clouds
# 6       15.14      PF  2022-11-14 18:32:08     overcast clouds
# 7       11.50      CL  2022-11-14 18:32:08       broken clouds
# 8        2.62      GL  2022-11-14 18:32:08     overcast clouds
# 9        7.00      US  2022-11-14 18:32:08     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Date', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"

new_column_order = ["City","Country","Lat","Lng","Max Temp", "Humidity","Cloudiness","Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Lavrentiya      RU  65.5833 -171.0000     17.71        79         100
# 1        Kandrian      PG  -6.2167  149.5500     75.61        89          89
# 2  Port Elizabeth      ZA -33.9180   25.5701     64.69        82           0
# 3       Saskylakh      RU  71.9167  114.0833    -11.40        90         100
# 4         Ahipara      NZ -35.1667  173.1667     62.31        77          26
# 5           Bluff      NZ -46.6000  168.3333     58.80        77          51
# 6         Rikitea      PF -23.1203 -134.9692     74.52        82         100
# 7    Punta Arenas      CL -53.1500  -70.9167     66.22        51          75
# 8         Aasiaat      GL  68.7098  -52.8699     16.27        99          99
# 9       Jamestown      US  42.0970  -79.2353     36.99        66         100
#
#    Wind Speed Current Description
# 0        4.25     overcast clouds
# 1        4.03     overcast clouds
# 2       20.71           clear sky
# 3       10.18     overcast clouds
# 4        5.57    scattered clouds
# 5       11.72       broken clouds
# 6       15.14     overcast clouds
# 7       11.50       broken clouds
# 8        2.62     overcast clouds
# 9        7.00     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file,index_label="City_ID")
